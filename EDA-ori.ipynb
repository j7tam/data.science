# %% [markdown]
# ### Prepare datasets

# %%
import pandas as pd
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt

ROOT = Path("Classes")
# Some paths have depth of 4 instead of 3, need to list them all out
files = [f for f in ROOT.rglob("*") if f.is_file() and not f.name.startswith(".")]
print("Total files found:", len(files))
# Out:
# Total files found: 102713

# %%
pd.set_option('display.max_colwidth', 100)

# %%
data = []
for f in files:
    try:
        with Image.open(f) as img:
            w, h = img.size
    except Exception:
        continue

    data.append([
        str(f),
        len(f.relative_to(ROOT).parts),
        f.stem,
        f.suffix.lstrip("."),
        w,
        h
    ])

data = pd.DataFrame(
    data,
    columns=["file_path", "depth", "file_name", "file_ext", "width", "height"]
)

data["aspect_ratio"] = data["width"] / data["height"]

# %%
print("File Depth Distribution:")
print(data.groupby('depth').size())
# Out:
# File Depth Distribution:
# depth
# 3    95999
# 4     6714
# dtype: int64

# %%
print("\nSample files with depth 3:")
data[data['depth'] == 3].head()
# Out:
# Sample files with depth 3:
#                                             file_path  depth file_name  \
# 0   Classes/conditionally_edible/horn_of_plenty/8.png      3         8
# 1   Classes/conditionally_edible/horn_of_plenty/9.png      3         9
# 2  Classes/conditionally_edible/horn_of_plenty/14.png      3        14
# 3  Classes/conditionally_edible/horn_of_plenty/12.png      3        12
# 4  Classes/conditionally_edible/horn_of_plenty/13.png      3        13
#
#   file_ext  width  height  aspect_ratio
# 0      png    512     512           1.0
# 1      png    512     512           1.0
# 2      png    512     512           1.0
# 3      png    512     512           1.0
# 4      png    512     512           1.0

# %%
print("\nSample files with depth 4:")
data[data['depth'] == 4].head()
# Out:
# Sample files with depth 4:
#                                                                  file_path  \
# 20454  Classes/conditionally_edible/Mushrooms/Agaricus/251_J9uSJkkBULQ.jpg
# 20455  Classes/conditionally_edible/Mushrooms/Agaricus/357__w_XUQZMZEw.jpg
# 20456  Classes/conditionally_edible/Mushrooms/Agaricus/374_Xap1L15Z8BM.jpg
# 20457  Classes/conditionally_edible/Mushrooms/Agaricus/442_bdfUNhioT1A.jpg
# 20458  Classes/conditionally_edible/Mushrooms/Agaricus/092_YzaMvFvqkiM.jpg
#
#        depth        file_name file_ext  width  height  aspect_ratio
# 20454      4  251_J9uSJkkBULQ      jpg    800     531      1.506591
# 20455      4  357__w_XUQZMZEw      jpg    800     600      1.333333
# 20456      4  374_Xap1L15Z8BM      jpg    777     600      1.295000
# 20457      4  442_bdfUNhioT1A      jpg    800     600      1.333333
# 20458      4  092_YzaMvFvqkiM      jpg    800     575      1.391304

# %%
data[data['depth'] == 4]['file_path'].apply(lambda x: x.split('/')[:-1]).value_counts().head()
# Out:
# file_path
# [Classes, conditionally_edible, Mushrooms, Lactarius]      1563
# [Classes, conditionally_edible, Mushrooms, Russula]        1148
# [Classes, conditionally_edible, Mushrooms, Boletus]        1073
# [Classes, conditionally_edible, Mushrooms, Cortinarius]     836
# [Classes, conditionally_edible, Mushrooms, Amanita]         750
# Name: count, dtype: int64

# %% [markdown]
# `Mushrooms` is redundant in the paths; the directory immediately after `Mushrooms/` represents the species label.

# %%
data['class'] = data['file_path'].apply(lambda x: x.split('/')[1])
data['species'] = data.apply(lambda x: x['file_path'].split('/')[3] if x['depth'] == 4 else x['file_path'].split('/')[2], axis=1)

# %%
data[data['depth'] == 3].head()
# Out:
#                                             file_path  depth file_name  \
# 0   Classes/conditionally_edible/horn_of_plenty/8.png      3         8
# 1   Classes/conditionally_edible/horn_of_plenty/9.png      3         9
# 2  Classes/conditionally_edible/horn_of_plenty/14.png      3        14
# 3  Classes/conditionally_edible/horn_of_plenty/12.png      3        12
# 4  Classes/conditionally_edible/horn_of_plenty/13.png      3        13
#
#   file_ext  width  height  aspect_ratio                 class         species
# 0      png    512     512           1.0  conditionally_edible  horn_of_plenty
# 1      png    512     512           1.0  conditionally_edible  horn_of_plenty
# 2      png    512     512           1.0  conditionally_edible  horn_of_plenty
# 3      png    512     512           1.0  conditionally_edible  horn_of_plenty
# 4      png    512     512           1.0  conditionally_edible  horn_of_plenty

# %%
data[data['depth'] == 4].head()
# Out:
#                                                                  file_path  \
# 20454  Classes/conditionally_edible/Mushrooms/Agaricus/251_J9uSJkkBULQ.jpg
# 20455  Classes/conditionally_edible/Mushrooms/Agaricus/357__w_XUQZMZEw.jpg
# 20456  Classes/conditionally_edible/Mushrooms/Agaricus/374_Xap1L15Z8BM.jpg
# 20457  Classes/conditionally_edible/Mushrooms/Agaricus/442_bdfUNhioT1A.jpg
# 20458  Classes/conditionally_edible/Mushrooms/Agaricus/092_YzaMvFvqkiM.jpg
#
#        depth        file_name file_ext  width  height  aspect_ratio  \
# 20454      4  251_J9uSJkkBULQ      jpg    800     531      1.506591
# 20455      4  357__w_XUQZMZEw      jpg    800     600      1.333333
# 20456      4  374_Xap1L15Z8BM      jpg    777     600      1.295000
# 20457      4  442_bdfUNhioT1A      jpg    800     600      1.333333
# 20458      4  092_YzaMvFvqkiM      jpg    800     575      1.391304
#
#                       class   species
# 20454  conditionally_edible  Agaricus
# 20455  conditionally_edible  Agaricus
# 20456  conditionally_edible  Agaricus
# 20457  conditionally_edible  Agaricus
# 20458  conditionally_edible  Agaricus

# %%
data['class'].value_counts(normalize=True)
# Out:
# class
# conditionally_edible    0.603312
# poisonous               0.205797
# edible                  0.179305
# deadly                  0.011586
# Name: proportion, dtype: float64

# %%
data.to_csv("mushroom_paths.csv", index=False)

# %% [markdown]
# ### Train-Test-Split

# %%
from sklearn.model_selection import train_test_split

# %%
mushroom_paths["label"] = mushroom_paths["class"].astype("category").cat.codes
label_map = dict(enumerate(mushroom_paths["class"].astype("category").cat.categories))
print("Label map:", label_map)
# Out:
# Label map: {0: 'conditionally_edible', 1: 'deadly', 2: 'edible', 3: 'poisonous'}

# %%
train_df, temp_df = train_test_split(
    mushroom_paths,
    test_size=0.25,
    stratify=mushroom_paths["label"]
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=0.5,
    stratify=temp_df["label"]
)

# %%
train_df.shape
# Out:
# (72006, 4)

# %%
test_df.shape
# Out:
# (12001, 4)

# %%
val_df.shape
# Out:
# (12001, 4)

# %%
from torch.utils.data import Dataset
from PIL import Image
import torch

# %%
class MushroomDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df.reset_index(drop=True)
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img = Image.open(row["path"]).convert("RGB")
        label = int(row["label"])

        if self.transform:
            img = self.transform(img)

        return img, label

# %% [markdown]
# #### Transform

# %%
from torchvision import transforms

# %%
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# %%
from torch.utils.data import DataLoader, WeightedRandomSampler

train_dataset = MushroomDataset(train_df, transform=train_transform)
val_dataset   = MushroomDataset(val_df, transform=val_transform)
test_dataset  = MushroomDataset(test_df, transform=val_transform)

class_counts = train_df["label"].value_counts().sort_index()
class_weights = 1.0 / torch.tensor(class_counts.values, dtype=torch.float)

sample_weights = class_weights[train_df["label"].values]

sampler = WeightedRandomSampler(
    weights=sample_weights,
    num_samples=len(sample_weights),
    replacement=True
)

train_loader = DataLoader(train_dataset, batch_size=32, sampler=sampler)
val_loader   = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
train_loader
